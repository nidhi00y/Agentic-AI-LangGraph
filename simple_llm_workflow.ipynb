# %%
from langgraph.graph import StateGraph,START, END
from langchain_openai import ChatOpenAI
from typing import TypedDict
from dotenv import load_dotenv
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 2
#       1 from langgraph.graph import StateGraph,START, END
# ----> 2 from langchain_openai import ChatOpenAI
#       3 from typing import TypedDict
#       4 from dotenv import load_dotenv
#
# File ~\OneDrive\Agentic_AI\myenv\Lib\site-packages\langchain_openai\__init__.py:4
#       1 """Module for OpenAI integrations."""
#       3 from langchain_openai._version import __version__
# ----> 4 from langchain_openai.chat_models import AzureChatOpenAI, ChatOpenAI
#       5 from langchain_openai.chat_models._client_utils import StreamChunkTimeoutError
#       6 from langchain_openai.embeddings import AzureOpenAIEmbeddings, OpenAIEmbeddings
#
# File ~\OneDrive\Agentic_AI\myenv\Lib\site-packages\langchain_openai\chat_models\__init__.py:3
#       1 """Module for OpenAI chat models."""
# ----> 3 from langchain_openai.chat_models.azure import AzureChatOpenAI
#       4 from langchain_openai.chat_models.base import ChatOpenAI
#       6 __all__ = ["AzureChatOpenAI", "ChatOpenAI"]
#
# File ~\OneDrive\Agentic_AI\myenv\Lib\site-packages\langchain_openai\chat_models\azure.py:20
#      17 from pydantic import BaseModel, Field, SecretStr, model_validator
#      18 from typing_extensions import Self
# ---> 20 from langchain_openai.chat_models.base import BaseChatOpenAI, _get_default_model_profile
#      22 if TYPE_CHECKING:
#      23     from langchain_core.language_models import ModelProfile
#
# File ~\OneDrive\Agentic_AI\myenv\Lib\site-packages\langchain_openai\chat_models\base.py:49
#      47 import certifi
#      48 import openai
# ---> 49 import tiktoken
#      50 from langchain_core.callbacks import (
#      51     AsyncCallbackManagerForLLMRun,
#      52     CallbackManagerForLLMRun,
#      53 )
#      54 from langchain_core.exceptions import (
#      55     ContextOverflowError,
#      56     ModelAPIError,
#    (...)     63     ModelTimeoutError,
#      64 )
#
# File ~\OneDrive\Agentic_AI\myenv\Lib\site-packages\tiktoken\__init__.py:2
#       1 # This is the public API of tiktoken
# ----> 2 from .core import Encoding as Encoding
#       3 from .model import encoding_for_model as encoding_for_model
#       4 from .model import encoding_name_for_model as encoding_name_for_model
#
# File ~\OneDrive\Agentic_AI\myenv\Lib\site-packages\tiktoken\core.py:7
#       4 from concurrent.futures import ThreadPoolExecutor
#       5 from typing import TYPE_CHECKING, AbstractSet, Collection, Literal, NoReturn, Sequence
# ----> 7 from tiktoken import _tiktoken
#       9 if TYPE_CHECKING:
#      10     import re
#
# ImportError: DLL load failed while importing _tiktoken: An Application Control policy has blocked this file.

# %%
load_dotenv()

# %%
model = ChatOpenAI()

# %%
class LLMState(TypedDict):
    question:str
    answer:str

# %%
def llm_qa(state:LLMState)->LLMState:
    question = state['question']
    prompt = f'Answer the foloowing question {question}'

    answer = model.invoke(prompt).content

    state['answer'] = answer
    return state

# %%
graph =  StateGraph(LLMState)

graph.add_node('llm_qa',llm_qa)

graph.add_edge(START,'llm_qa')
graph.add_edge('llm_qa',END)

workflow = graph.compile()

# %%
initial_state = {'question':'How far is the moon from earth'}
final_state = workflow.invoke(initial_state)
print(final_state['answer'])
